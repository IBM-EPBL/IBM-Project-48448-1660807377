# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (3.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
import keras
from keras.preprocessing import image
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.models import load_model
from keras.applications.vgg19 import VGG19,preprocess_input,decode_predictions

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='d7kBTRgxhPf1eTJln-LYd7Uj6zaKk8Xxz0377KmKCPwc',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.private.us.cloud-object-storage.appdomain.cloud')

bucket = 'vegetablemodel-donotdelete-pr-ebiegs0nxqvy90'
object_key = 'Veg-dataset.zip'

streaming_body_2 = cos_client.get_object(Bucket=bucket, Key=object_key)['Body']

# Your data file was loaded into a botocore.response.StreamingBody object.
# Please read the documentation of ibm_boto3 and pandas to learn more about the possibilities to load the data.
# ibm_boto3 documentation: https://ibm.github.io/ibm-cos-sdk-python/
# pandas documentation: http://pandas.pydata.org/

# %%
from io import BytesIO
import zipfile
unzip = zipfile.ZipFile(BytesIO(streaming_body_2.read()), "r")
file_paths = unzip.namelist() 
for path in file_paths:
    unzip.extract(path)

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
os.listdir('/home/wsuser/work/Veg-dataset/train_set')
# Out:
# ['Pepper,_bell___healthy',
#  'Potato___Late_blight',
#  'Pepper,_bell___Bacterial_spot',
#  'Tomato___Bacterial_spot',
#  'Potato___Early_blight',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Leaf_Mold',
#  'Potato___healthy',
#  'Tomato___Late_blight']

# %%
train_datagen=ImageDataGenerator(zoom_range=0.5,shear_range=0.3,horizontal_flip=True,preprocessing_function=preprocess_input)
val_datagen=ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train=train_datagen.flow_from_directory('/home/wsuser/work/Veg-dataset/test_set',target_size=(256,256),batch_size=32)

val=val_datagen.flow_from_directory('/home/wsuser/work/Veg-dataset/train_set',target_size=(256,256),batch_size=32)
# Out:
# Found 3416 images belonging to 9 classes.
# Found 11386 images belonging to 9 classes.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from scipy) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy

# %%
t_img,label=train.next()

# %%
t_img.shape
# Out:
# (32, 256, 256, 3)

# %%
def plotImage(imgarr,label):
      for im,l in zip(imgarr,label):         
            plt.figure(figsize=(5,5))
            plt.imshow(im/255)
            plt.show()

# %%
plotImage(t_img[:3],label[:3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from keras.layers import Dense,Flatten
from keras.models import Model
from keras.applications.vgg19 import VGG19
import keras

# %%
base_model=VGG19(input_shape=(256,256,3),include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable=False

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
X=Flatten()(base_model.output)
X=Dense(units=9,activation='softmax')(X)

model=Model(base_model.input,X)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 9)                 294921
#
# =================================================================
# Total params: 20,319,305
# Trainable params: 294,921
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss=keras.losses.categorical_crossentropy,metrics=['accuracy'])

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping

es=EarlyStopping(monitor='val_accuracy',min_delta=0.01,patience=3,verbose=1)

mc=ModelCheckpoint(filepath='veg_model.h5',monitor='val_accuracy',min_delta=0.01,patience=3,verbose=1,save_best_only=True)


cb=[es,mc]

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dense_1 (Dense)             (None, 9)                 294921
#
# =================================================================
# Total params: 20,319,305
# Trainable params: 294,921
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
model.fit_generator(train,steps_per_epoch=16,epochs=50,verbose=1,callbacks=cb,validation_data=val,validation_steps=16)
# Out:
# /tmp/wsuser/ipykernel_165/1613728924.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train,steps_per_epoch=16,epochs=50,verbose=1,callbacks=cb,validation_data=val,validation_steps=16)
# Epoch 1/50
# 16/16 [==============================] - ETA: 0s - loss: 12.3356 - accuracy: 0.4345
# Epoch 00001: val_accuracy improved from -inf to 0.72656, saving model to veg_model.h5
# 16/16 [==============================] - 422s 27s/step - loss: 12.3356 - accuracy: 0.4345 - val_loss: 4.1749 - val_accuracy: 0.7266
# Epoch 2/50
# 16/16 [==============================] - ETA: 0s - loss: 4.4968 - accuracy: 0.7441
# Epoch 00002: val_accuracy improved from 0.72656 to 0.78320, saving model to veg_model.h5
# 16/16 [==============================] - 427s 28s/step - loss: 4.4968 - accuracy: 0.7441 - val_loss: 3.6214 - val_accuracy: 0.7832
# Epoch 3/50
# 16/16 [==============================] - ETA: 0s - loss: 4.6709 - accuracy: 0.7773
# Epoch 00003: val_accuracy improved from 0.78320 to 0.84570, saving model to veg_model.h5
# 16/16 [==============================] - 428s 28s/step - loss: 4.6709 - accuracy: 0.7773 - val_loss: 4.0318 - val_accuracy: 0.8457
# Epoch 4/50
# 16/16 [==============================] - ETA: 0s - loss: 3.8642 - accuracy: 0.8105
# Epoch 00004: val_accuracy did not improve from 0.84570
# 16/16 [==============================] - 430s 28s/step - loss: 3.8642 - accuracy: 0.8105 - val_loss: 5.1287 - val_accuracy: 0.7676
# Epoch 5/50
# 16/16 [==============================] - ETA: 0s - loss: 3.4445 - accuracy: 0.8164
# Epoch 00005: val_accuracy improved from 0.84570 to 0.86719, saving model to veg_model.h5
# 16/16 [==============================] - 421s 27s/step - loss: 3.4445 - accuracy: 0.8164 - val_loss: 1.8937 - val_accuracy: 0.8672
# Epoch 6/50
# 16/16 [==============================] - ETA: 0s - loss: 3.9935 - accuracy: 0.8095
# Epoch 00006: val_accuracy did not improve from 0.86719
# 16/16 [==============================] - 422s 27s/step - loss: 3.9935 - accuracy: 0.8095 - val_loss: 3.5789 - val_accuracy: 0.8574
# Epoch 7/50
# 16/16 [==============================] - ETA: 0s - loss: 2.8925 - accuracy: 0.8373
# Epoch 00007: val_accuracy improved from 0.86719 to 0.86914, saving model to veg_model.h5
# 16/16 [==============================] - 423s 27s/step - loss: 2.8925 - accuracy: 0.8373 - val_loss: 2.9747 - val_accuracy: 0.8691
# Epoch 8/50
# 16/16 [==============================] - ETA: 0s - loss: 3.3125 - accuracy: 0.8359
# Epoch 00008: val_accuracy improved from 0.86914 to 0.89258, saving model to veg_model.h5
# 16/16 [==============================] - 420s 27s/step - loss: 3.3125 - accuracy: 0.8359 - val_loss: 1.7890 - val_accuracy: 0.8926
# Epoch 9/50
# 16/16 [==============================] - ETA: 0s - loss: 2.5454 - accuracy: 0.8555
# Epoch 00009: val_accuracy did not improve from 0.89258
# 16/16 [==============================] - 419s 27s/step - loss: 2.5454 - accuracy: 0.8555 - val_loss: 2.7961 - val_accuracy: 0.8711
# Epoch 10/50
# 16/16 [==============================] - ETA: 0s - loss: 2.2550 - accuracy: 0.8809
# Epoch 00010: val_accuracy did not improve from 0.89258
# 16/16 [==============================] - 424s 27s/step - loss: 2.2550 - accuracy: 0.8809 - val_loss: 3.1102 - val_accuracy: 0.8477
# Epoch 11/50
# 16/16 [==============================] - ETA: 0s - loss: 2.6038 - accuracy: 0.8535
# Epoch 00011: val_accuracy improved from 0.89258 to 0.91016, saving model to veg_model.h5
# 16/16 [==============================] - 420s 27s/step - loss: 2.6038 - accuracy: 0.8535 - val_loss: 1.9053 - val_accuracy: 0.9102
# Epoch 12/50
# 16/16 [==============================] - ETA: 0s - loss: 2.8156 - accuracy: 0.8672
# Epoch 00012: val_accuracy improved from 0.91016 to 0.91992, saving model to veg_model.h5
# 16/16 [==============================] - 428s 28s/step - loss: 2.8156 - accuracy: 0.8672 - val_loss: 1.6583 - val_accuracy: 0.9199
# Epoch 13/50
# 16/16 [==============================] - ETA: 0s - loss: 2.4597 - accuracy: 0.8906
# Epoch 00013: val_accuracy did not improve from 0.91992
# 16/16 [==============================] - 423s 27s/step - loss: 2.4597 - accuracy: 0.8906 - val_loss: 3.2975 - val_accuracy: 0.8711
# Epoch 14/50
# 16/16 [==============================] - ETA: 0s - loss: 3.3991 - accuracy: 0.8516
# Epoch 00014: val_accuracy improved from 0.91992 to 0.92188, saving model to veg_model.h5
# 16/16 [==============================] - 424s 27s/step - loss: 3.3991 - accuracy: 0.8516 - val_loss: 2.6597 - val_accuracy: 0.9219
# Epoch 15/50
# 16/16 [==============================] - ETA: 0s - loss: 2.1305 - accuracy: 0.9004
# Epoch 00015: val_accuracy did not improve from 0.92188
# 16/16 [==============================] - 429s 28s/step - loss: 2.1305 - accuracy: 0.9004 - val_loss: 6.1092 - val_accuracy: 0.8574
# Epoch 16/50
# 16/16 [==============================] - ETA: 0s - loss: 2.2524 - accuracy: 0.8926
# Epoch 00016: val_accuracy did not improve from 0.92188
# 16/16 [==============================] - 421s 27s/step - loss: 2.2524 - accuracy: 0.8926 - val_loss: 2.0746 - val_accuracy: 0.8945
# Epoch 17/50
# 16/16 [==============================] - ETA: 0s - loss: 2.3686 - accuracy: 0.8926
# Epoch 00017: val_accuracy did not improve from 0.92188
# 16/16 [==============================] - 420s 27s/step - loss: 2.3686 - accuracy: 0.8926 - val_loss: 3.0351 - val_accuracy: 0.8809
# Epoch 00017: early stopping

# %%
ls
# Out:
# Veg-dataset/  veg_model.h5

# %%
model.save('veg.h5')

# %%
# !tar -zcvf veg-model_new.tgz veg.h5
# Out:
# veg.h5

# %%
ls -1
# Out:
# Veg-dataset/
# veg.h5
# veg_model.h5
# veg-model_new.tgz

# %%
# !pip install watson-machine-learning-client --upgrade
# Out:
# Collecting watson-machine-learning-client
#   Downloading watson_machine_learning_client-1.0.391-py3-none-any.whl (538 kB)
#      |████████████████████████████████| 538 kB 14.6 MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (2.26.0)
# Requirement already satisfied: certifi in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (2022.9.24)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (1.3.4)
# Requirement already satisfied: lomond in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (0.3.3)
# Requirement already satisfied: ibm-cos-sdk in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (2.11.0)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (1.26.7)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (0.8.9)
# Requirement already satisfied: tqdm in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (4.62.3)
# Requirement already satisfied: boto3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from watson-machine-learning-client) (1.18.21)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from boto3->watson-machine-learning-client) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from boto3->watson-machine-learning-client) (0.5.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.21 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from boto3->watson-machine-learning-client) (1.21.41)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from botocore<1.22.0,>=1.21.21->boto3->watson-machine-learning-client) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.21->boto3->watson-machine-learning-client) (1.15.0)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.11.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cos-sdk->watson-machine-learning-client) (2.11.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.11.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from ibm-cos-sdk->watson-machine-learning-client) (2.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->watson-machine-learning-client) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from requests->watson-machine-learning-client) (2.0.4)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from pandas->watson-machine-learning-client) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/envs/Python-3.9/lib/python3.9/site-packages (from pandas->watson-machine-learning-client) (1.20.3)
# Installing collected packages: watson-machine-learning-client
# Successfully installed watson-machine-learning-client-1.0.391

# %%
from ibm_watson_machine_learning import APIClient

wml_credentials = {
                    "url": "https://us-south.ml.cloud.ibm.com",
                   "apikey":"0DiFaicnrhpT4V2AVYgRMLrZnnOrzIpC1gbDn7PcNoJW" 
                  }

client = APIClient(wml_credentials)

# %%
def guid_from_space_name(client, space_name): 
    space = client.spaces.get_details()
    return(next(item for item in space['resources'] if item['entity']["name"]==space_name)['metadata']['id'])

# %%
space_uid = guid_from_space_name(client, 'Vegetable_model') 
print("Space UID = " + space_uid)
# Out:
# Space UID = bcb94031-1661-4d1e-a407-8bbfdfa25ed0

# %%
client.set.default_space(space_uid)
# Out:
# 'SUCCESS'

# %%
client.software_specifications.list()
# Out:
# -----------------------------  ------------------------------------  ----
# NAME                           ASSET_ID                              TYPE
# default_py3.6                  0062b8c9-8b7d-44a0-a9b9-46c416adcbd9  base
# kernel-spark3.2-scala2.12      020d69ce-7ac1-5e68-ac1a-31189867356a  base
# pytorch-onnx_1.3-py3.7-edt     069ea134-3346-5748-b513-49120e15d288  base
# scikit-learn_0.20-py3.6        09c5a1d0-9c1e-4473-a344-eb7b665ff687  base
# spark-mllib_3.0-scala_2.12     09f4cff0-90a7-5899-b9ed-1ef348aebdee  base
# pytorch-onnx_rt22.1-py3.9      0b848dd4-e681-5599-be41-b5f6fccc6471  base
# ai-function_0.1-py3.6          0cdb0f1e-5376-4f4d-92dd-da3b69aa9bda  base
# shiny-r3.6                     0e6e79df-875e-4f24-8ae9-62dcc2148306  base
# tensorflow_2.4-py3.7-horovod   1092590a-307d-563d-9b62-4eb7d64b3f22  base
# pytorch_1.1-py3.6              10ac12d6-6b30-4ccd-8392-3e922c096a92  base
# tensorflow_1.15-py3.6-ddl      111e41b3-de2d-5422-a4d6-bf776828c4b7  base
# autoai-kb_rt22.2-py3.10        125b6d9a-5b1f-5e8d-972a-b251688ccf40  base
# runtime-22.1-py3.9             12b83a17-24d8-5082-900f-0ab31fbfd3cb  base
# scikit-learn_0.22-py3.6        154010fa-5b3b-4ac1-82af-4d5ee5abbc85  base
# default_r3.6                   1b70aec3-ab34-4b87-8aa0-a4a3c8296a36  base
# pytorch-onnx_1.3-py3.6         1bc6029a-cc97-56da-b8e0-39c3880dbbe7  base
# kernel-spark3.3-r3.6           1c9e5454-f216-59dd-a20e-474a5cdf5988  base
# pytorch-onnx_rt22.1-py3.9-edt  1d362186-7ad5-5b59-8b6c-9d0880bde37f  base
# tensorflow_2.1-py3.6           1eb25b84-d6ed-5dde-b6a5-3fbdf1665666  base
# spark-mllib_3.2                20047f72-0a98-58c7-9ff5-a77b012eb8f5  base
# tensorflow_2.4-py3.8-horovod   217c16f6-178f-56bf-824a-b19f20564c49  base
# runtime-22.1-py3.9-cuda        26215f05-08c3-5a41-a1b0-da66306ce658  base
# do_py3.8                       295addb5-9ef9-547e-9bf4-92ae3563e720  base
# autoai-ts_3.8-py3.8            2aa0c932-798f-5ae9-abd6-15e0c2402fb5  base
# tensorflow_1.15-py3.6          2b73a275-7cbf-420b-a912-eae7f436e0bc  base
# kernel-spark3.3-py3.9          2b7961e2-e3b1-5a8c-a491-482c8368839a  base
# pytorch_1.2-py3.6              2c8ef57d-2687-4b7d-acce-01f94976dac1  base
# spark-mllib_2.3                2e51f700-bca0-4b0d-88dc-5c6791338875  base
# pytorch-onnx_1.1-py3.6-edt     32983cea-3f32-4400-8965-dde874a8d67e  base
# spark-mllib_3.0-py37           36507ebe-8770-55ba-ab2a-eafe787600e9  base
# spark-mllib_2.4                390d21f8-e58b-4fac-9c55-d7ceda621326  base
# autoai-ts_rt22.2-py3.10        396b2e83-0953-5b86-9a55-7ce1628a406f  base
# xgboost_0.82-py3.6             39e31acd-5f30-41dc-ae44-60233c80306e  base
# pytorch-onnx_1.2-py3.6-edt     40589d0e-7019-4e28-8daa-fb03b6f4fe12  base
# pytorch-onnx_rt22.2-py3.10     40e73f55-783a-5535-b3fa-0c8b94291431  base
# default_r36py38                41c247d3-45f8-5a71-b065-8580229facf0  base
# autoai-ts_rt22.1-py3.9         4269d26e-07ba-5d40-8f66-2d495b0c71f7  base
# autoai-obm_3.0                 42b92e18-d9ab-567f-988a-4240ba1ed5f7  base
# pmml-3.0_4.3                   493bcb95-16f1-5bc5-bee8-81b8af80e9c7  base
# spark-mllib_2.4-r_3.6          49403dff-92e9-4c87-a3d7-a42d0021c095  base
# xgboost_0.90-py3.6             4ff8d6c2-1343-4c18-85e1-689c965304d3  base
# pytorch-onnx_1.1-py3.6         50f95b2a-bc16-43bb-bc94-b0bed208c60b  base
# autoai-ts_3.9-py3.8            52c57136-80fa-572e-8728-a5e7cbb42cde  base
# spark-mllib_2.4-scala_2.11     55a70f99-7320-4be5-9fb9-9edb5a443af5  base
# spark-mllib_3.0                5c1b0ca2-4977-5c2e-9439-ffd44ea8ffe9  base
# autoai-obm_2.0                 5c2e37fa-80b8-5e77-840f-d912469614ee  base
# spss-modeler_18.1              5c3cad7e-507f-4b2a-a9a3-ab53a21dee8b  base
# cuda-py3.8                     5d3232bf-c86b-5df4-a2cd-7bb870a1cd4e  base
# runtime-22.2-py3.10-xc         5e8cddff-db4a-5a6a-b8aa-2d4af9864dab  base
# autoai-kb_3.1-py3.7            632d4b22-10aa-5180-88f0-f52dfb6444d7  base
# -----------------------------  ------------------------------------  ----
# Note: Only first 50 records were displayed. To display more use 'limit' parameter.

# %%
software_space_uid = client.software_specifications.get_uid_by_name("tensorflow_rt22.1-py3.9")
software_space_uid
# Out:
# 'acd9c798-6974-5d2f-a657-ce06e986df4d'

# %%
model_details = client.repository.store_model(model= 'veg-model_new.tgz',
    meta_props={
        client.repository.ModelMetaNames.NAME:"CNN",
        client.repository.ModelMetaNames.TYPE:"tensorflow_2.7",
        client.repository.ModelMetaNames.SOFTWARE_SPEC_UID:software_space_uid}
    )

# %%
model_id = client.repository.get_model_id(model_details)

# %%
model_id
# Out:
# '2876d33d-f02e-4b13-bb40-9bccc33d1a46'

# %%
ls
# Out:
# Veg-dataset/  veg.h5  veg_model.h5  veg-model_new.tgz

# %%
model1=load_model('veg.h5')

# %%
imge=tensorflow.keras.utils.load_img(r'/home/wsuser/work/Veg-dataset/test_set/Potato___Early_blight/b6220993-c51f-48fa-bee9-fb5cb89cc0c4___RS_Early.B 7467.JPG',target_size=(256,256))

# %%
imge
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FBABC633460>

# %%
x=img_to_array(imge)
im=preprocess_input(x)
image1=np.expand_dims(im,axis=0)

# %%
pred=np.argmax(model1.predict(image1))

# %%
if pred == 0:
    print ("Pepper bell Bacterial_spot")
if pred == 1:
    print (" Pepper bell healthy")
if pred == 2:
    print ("Potato Early blight")
if pred == 3:
    print ("Potato___healthy")
if pred == 4:
    print ("Potato Late blight")
if pred == 5:
    print ("Tomato Bacterial spot")
if pred == 6:
    print ("Tomato Late blight")
if pred == 7:
    print ("Tomato Leaf Mold")
if pred == 8:
    print ("Tomato Septoria leaf spot")
# Out:
# Potato Early blight
